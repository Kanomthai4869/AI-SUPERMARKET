# %% [markdown]
# <a href="https://colab.research.google.com/github/Kanomthai4869/AI-SUPERMARKET/blob/main/train_rgb_depth_weight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("test")
# Out:
# test
